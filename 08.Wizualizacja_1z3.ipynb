# %% [markdown]
# # Warsztaty Python w Data Science
#
# ---
# ## Wizualizacja danych
# ### Część 1 z 3
#
# - Wykresy w matplotlib
# - Matplotlib a pandas
# - Facetting - różne wizualizacje dla _*1*_ zbioru danych
# ---

# %% [markdown]
# #  Matplotlib

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
plt.style.use("classic")
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("fivethirtyeight")
x = np.linspace(0, 10, 100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--');

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use("dark_background")
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %%
plt.style.use("dark_background")
plt.grid(None)
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');


plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.grid(axis="x")
plt.plot(x, y, 'o', color='yellow');

# %%
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.grid(axis="y")

plt.plot(x, y, 'x', color='yellow');

# %%
plt.figure(figsize=(20,10))
plt.style.use("dark_background")
x = np.linspace(0, 10, 30)
y = np.sin(x)
plt.grid(axis="y")

plt.plot(x, y, '^', color='yellow');

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax.bar(langs,students, color="green")
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax.bar(langs,students, alpha=.3)
ax.plot(students)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

data = [[30, 25, 50, 20],
        [40, 23, 51, 17],
        [35, 22, 45, 19]]

X = np.arange(4)
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
ax.bar(X + 0.00, data[0], color = 'b', width = 0.25)
ax.bar(X + 0.25, data[1], color = 'g', width = 0.25)
ax.bar(X + 0.50, data[2], color = 'r', width = 0.25);

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
ind = np.arange(N) # index grupy
width = 0.35
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])

ax.bar(ind, menMeans, width, color='b')
ax.bar(ind, womenMeans, width,bottom=menMeans, color='r')

ax.set_ylabel('Wyniki')
ax.set_title('Wyniki w rozbiciu na grupy i płeć')
ax.set_xticklabels(['', 'G1', 'G2', 'G3', 'G4', 'G5'])
ax.set_yticks(np.arange(0, 81, 10))
ax.legend(labels=['Mężczyźni', 'Kobiety'])
plt.show();

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
a1 = fig.add_axes([0,0,2,1])
x = np.arange(1,11)

a1.set_title('Wykres z dwoma osiami Y')
a1.plot(x,np.exp(x))
a1.set_ylabel('exp')
a1.legend(labels = ('exp',), loc='lower right')
a1.grid(False)

a2 = a1.twinx()

a2.plot(x, np.log(x), 
        linestyle='-', 
        marker='s', 
        color='r',
        linewidth=2,
        markersize=8,
        markeredgewidth=2,
        markeredgecolor='black')

a2.set_ylabel('log')
a2.grid(False)
a2.legend(labels = ('log',), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
a1 = fig.add_axes([0,0,2,1])
x = np.arange(1,11)

a1.set_title('Wykres z dwoma osiami Y')
a1.plot(x,np.exp(x))
a1.set_ylabel('exp with log scaling')
a1.legend(labels = ('exp',), loc='lower right')
a1.grid(False)
a1.set_yscale('log')

a2 = a1.twinx()

a2.plot(x, np.log(x), 
        linestyle='-', 
        marker='s', 
        color='r',
        linewidth=2,
        markersize=8,
        markeredgewidth=2,
        markeredgecolor='black')

a2.set_ylabel('log')
a2.grid(False)
a2.legend(labels = ('log',), loc='upper left')
plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
# układ współrzędnych biegunowy
plt.axes(projection = 'polar') 
    
# Wartości kąta w radianach 
rads = np.arange(0, (4 * np.pi), 0.1) 
  
for rad in rads: 
    plt.polar(rad, rad/2, 'r.') 

plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt 

# układ współrzędnych biegunowy
plt.axes(projection = 'polar') 
  
# Promień
r = 2
  
# Wartości kąta w radianach 
rads = np.arange(0, (4 * np.pi), 0.05) 
  
for rad in rads: 
    plt.polar(rad, r, 'r.') 

plt.show()

# %%
import matplotlib.pyplot as plt

ax=plt.gca() # Get Current Axes

circle=plt.Circle((0,0),2)
ax.add_patch(circle)
plt.axis('scaled')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Pandas a matplotlib

# %%
import pandas as pd
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts
# Out:
# 2000-01-01    0.007600
# 2000-01-02    0.312445
# 2000-01-03   -1.250960
# 2000-01-04    0.880280
# 2000-01-05   -1.510725
#                 ...
# 2002-09-22   -0.994873
# 2002-09-23   -1.741287
# 2002-09-24   -0.616242
# 2002-09-25   -1.668708
# 2002-09-26   -1.029877
# Freq: D, Length: 1000, dtype: float64

# %%
ts.cumsum()
# Out:
# 2000-01-01     0.007600
# 2000-01-02     0.320045
# 2000-01-03    -0.930915
# 2000-01-04    -0.050635
# 2000-01-05    -1.561360
#                 ...
# 2002-09-22   -33.163162
# 2002-09-23   -34.904449
# 2002-09-24   -35.520691
# 2002-09-25   -37.189399
# 2002-09-26   -38.219276
# Freq: D, Length: 1000, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
df
# Out:
#                     A          B         C          D
# 2000-01-01  -0.777278   0.714827  1.304374  -0.059361
# 2000-01-02   0.489505  -0.008378  1.432182   1.690153
# 2000-01-03   1.288734  -0.213402  0.831931   0.281969
# 2000-01-04   0.310821  -0.833242  0.268936   1.096557
# 2000-01-05  -0.889619  -0.969822  0.497130   2.352431
# ...               ...        ...       ...        ...
# 2002-09-22  18.137219 -53.369101  7.670496  24.508073
# 2002-09-23  20.382991 -53.279314  7.343688  23.794902
# 2002-09-24  20.175057 -53.070708  6.185552  22.303839
# 2002-09-25  20.456542 -51.970380  7.313705  22.773762
# 2002-09-26  21.508542 -52.415357  5.580321  22.692723
#
# [1000 rows x 4 columns]

# %%
df.plot();

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

drange = pd.date_range(start='2015-07-01', end='2015-07-10', freq='D')
df = pd.DataFrame(data=np.random.random_sample((10, 3)), index=drange, columns=['col1', 'col2', 'col3'])
df
# Out:
#                 col1      col2      col3
# 2015-07-01  0.066689  0.778073  0.261348
# 2015-07-02  0.525525  0.177715  0.198645
# 2015-07-03  0.603967  0.396457  0.759191
# 2015-07-04  0.306495  0.735292  0.585897
# 2015-07-05  0.262478  0.379029  0.669370
# 2015-07-06  0.336465  0.358125  0.208487
# 2015-07-07  0.626162  0.962422  0.798141
# 2015-07-08  0.603541  0.194760  0.667337
# 2015-07-09  0.895703  0.408972  0.751757
# 2015-07-10  0.770859  0.216708  0.472828

# %%
fig, ax = plt.subplots()

df[['col1', 'col2']].plot(kind='bar', ax=ax, stacked=True)

ax.grid(True)

x = ax.legend(loc='best')

# %% [markdown]
# ---

# %% [markdown]
# # Facetting
#
# Facetting - rozdzielenie wykresu na kilka wykresów o tych samych osiach

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 5)
fig = plt.figure()

fig.add_subplot(221)   # top left
plt.plot(np.cos(x))
fig.add_subplot(222)   # top right
plt.plot(np.sin(x))
fig.add_subplot(223)   # bottom left
plt.plot(np.tan(x))
fig.add_subplot(224)   # bottom right 
plt.plot(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

u = np.linspace(-1, 1, 100)

plt.subplot(211)
plt.plot(u,np.sqrt(1-u*u))
plt.plot(u,-np.sqrt(1-u*u))

plt.subplot(212)
plt.plot(u,np.sqrt(1-u*u))
plt.plot(u,-np.sqrt(1-u*u))

plt.axis('equal')

plt.show()

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/bike+sharing+dataset

# %% [markdown]
# https://www.kdnuggets.com/2019/04/data-visualization-python-matplotlib-seaborn.html

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

day = pd.read_csv('.\data\day.csv')

# %%
day
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
plt.scatter('temp', 'cnt', data=day)
plt.xlabel('Znormalizowana Temperatura', fontsize='large')
plt.ylabel('Ilość wypożyczeń rowerów', fontsize='large');

# %%
plt.scatter('temp', 'cnt', data=day, c='season')
plt.xlabel('Znormalizowana Temperatura', fontsize='large')
plt.ylabel('Ilość wypożyczeń rowerów', fontsize='large');

# %%
plt.rcParams['figure.figsize'] = [15, 10]

fontdict={'fontsize': 18,
          'weight' : 'bold',
         'horizontalalignment': 'center'}

fontdictx={'fontsize': 18,
          'weight' : 'bold',
          'horizontalalignment': 'center'}

fontdicty={'fontsize': 16,
          'weight' : 'bold',
          'verticalalignment': 'baseline',
          'horizontalalignment': 'center'}

winter = plt.scatter('temp', 'cnt', data=day[day['season']==1], marker='o', color='blue')
spring = plt.scatter('temp', 'cnt', data=day[day['season']==2], marker='v', color='green')
summer = plt.scatter('temp', 'cnt', data=day[day['season']==3], marker='s', color='orange')
autumn = plt.scatter('temp', 'cnt', data=day[day['season']==4], marker='^', color='brown')

plt.legend(handles=(winter,spring,summer,autumn),
           labels=( 'Zima', 'Wiosna', 'Lato', 'Jesień'),
           title="Pora roku", title_fontsize=16,
           scatterpoints=1,
           bbox_to_anchor=(1, 0.7), loc=2, borderaxespad=1.,
           ncol=1,
           fontsize=14)
plt.grid()
plt.title('Ilość wypożyczeń rowerów względem temperatury', fontdict=fontdict, color="white")
plt.xlabel("Znormalizowana temperatura", fontdict=fontdictx)
plt.ylabel("Ilość Wypozyczeń", fontdict=fontdicty);

# %% [markdown]
# ### Ten wykres ma chyba następujące problemy
# - dane się nakładają na siebie
# - jest nieczytelny
# - nie widać dobrze różnic między porami roku
# - nie widać trendów
# - wydaje się, że temperatura jest pozytywnie skorelowana z z ilością wypożyczeń

# %%
fig = plt.figure()

plt.rcParams['figure.figsize'] = [15,10]
plt.rcParams["font.weight"] = "bold"

fontdict={'fontsize': 25,
          'weight' : 'bold'}

fontdicty={'fontsize': 18,
          'weight' : 'bold',
          'verticalalignment': 'baseline',
          'horizontalalignment': 'center'}

fontdictx={'fontsize': 18,
          'weight' : 'bold',
          'horizontalalignment': 'center'}

plt.subplots_adjust(wspace=0.2, hspace=0.2)

fig.suptitle('Ilość wypożyczeń rowerów względem temperatury\nz rozbiciem na pory roku', fontsize=25,fontweight="bold", color="white", 
             position=(0.5,1.01))

ax1 = fig.add_subplot(221)
ax1.grid()
ax1.scatter('temp', 'cnt', data=day[day['season']==1], c="blue")
ax1.set_title('Zima', fontdict=fontdict, color="blue")
ax1.set_ylabel("Ilość wypożyczeń", fontdict=fontdicty, position=(0,-0.1))


ax2 = fig.add_subplot(222)
ax2.grid()
ax2.scatter('temp', 'cnt', data=day[day['season']==2], c="green")
ax2.set_title("Wiosna", fontdict=fontdict, color="green")



ax3 = fig.add_subplot(223)
ax3.grid()
ax3.scatter('temp', 'cnt', data=day[day['season']==3], c="orange")
ax3.set_title('Lato', fontdict=fontdict, color="orange")


ax4 = fig.add_subplot(224)
ax4.grid()
ax4.scatter('temp', 'cnt', data=day[day['season']==4], c="brown")
ax4.set_title('Jesień', fontdict=fontdict, color="brown")
ax4.set_xlabel("Znormalizowana temperatura", fontdict=fontdictx, position=(-0.1,0));

# %% [markdown]
# ## Tym razem
# - Zimą jest pozytywna korelacja
# - Ale na wiosnę i jesień jest lekka korelacja kwadratowa (?)
# - W lecie ma widać jakichś trendów

# %%
fig = plt.figure()

plt.rcParams['figure.figsize'] = [12,12]
plt.rcParams["font.weight"] = "bold"

plt.subplots_adjust(hspace=0.60)


fontdicty={'fontsize': 20,
          'weight' : 'bold',
          'verticalalignment': 'baseline',
          'horizontalalignment': 'center'}

fontdictx={'fontsize': 20,
          'weight' : 'bold',
          'horizontalalignment': 'center'}

fig.suptitle('Ilość wypożyczeń rowerów względem temperatury\nz rozbiciem na pory roku', fontsize=25,fontweight="bold", color="white", 
             position=(0.5,1.0))

#ax2 is defined first because the other plots are sharing its x-axis
ax2 = fig.add_subplot(412, sharex=ax2)
ax2.grid()
ax2.scatter('temp', 'cnt', data=day.loc[day['season']==2], c="green")
ax2.set_title('Wiosna', fontdict=fontdict, color="green")
ax2.set_ylabel("Ilość wypożyczeń", fontdict=fontdicty, position=(-0.3,-0.2))


ax1 = fig.add_subplot(411, sharex=ax2)
ax1.grid()
ax1.scatter('temp', 'cnt', data=day.loc[day['season']==1], c="blue")
ax1.set_title('Zima', fontdict=fontdict, color="blue")


ax3 = fig.add_subplot(413, sharex=ax2)
ax3.grid()
ax3.scatter('temp', 'cnt', data=day.loc[day['season']==3], c="orange")
ax3.set_title('Lato', fontdict=fontdict, color="orange")


ax4 = fig.add_subplot(414, sharex=ax2)
ax4.grid()
ax4.scatter('temp', 'cnt', data=day.loc[day['season']==4], c="brown")
ax4.set_title('Jesień', fontdict=fontdict, color="brown")
ax4.set_xlabel("Znormalizowana temperatura", fontdict=fontdictx);

# %% [markdown]
# - Zima ma najniższe temperatury!
# - Lato ma najwyższe temperatury
# - Wiosną i latem relacja jest kwadratowa (parabola)
# - W niższych temperaturach - zawsze jest mniej pożyczanych rowerów
# - Zimą jest wyraźna pozytywna korelacja
# - Latem mamy lekko negatywną korelację

# %%
fig = plt.figure()

plt.rcParams['figure.figsize'] = [10,10]
plt.rcParams["font.weight"] = "bold"

plt.subplots_adjust(wspace=0.5)
fontdicty1={'fontsize': 18,
          'weight' : 'bold'}

fontdictx1={'fontsize': 18,
          'weight' : 'bold',
          'horizontalalignment': 'center'}

fig.suptitle('Ilość wypożyczeń rowerów względem temperatury\nz rozbiciem na pory roku', fontsize=25,fontweight="bold", color="white", 
             position=(0.5,1.0))

ax3 = fig.add_subplot(143, sharey=ax3)
ax3.scatter('temp', 'cnt', data=day.loc[day['season']==3], c="orange")
ax3.set_title('Lato', fontdict=fontdict,color="orange")
ax3.grid()

ax1 = fig.add_subplot(141, sharey=ax3)
ax1.scatter('temp', 'cnt', data=day.loc[day['season']==1], c="blue")
ax1.set_title('Zima', fontdict=fontdict, color="blue")
ax1.set_ylabel("Wypożyczenia rowerów", fontdict=fontdicty1, position=(0.5,0.5))
ax1.grid()

ax2 = fig.add_subplot(142, sharey=ax3)
ax2.scatter('temp', 'cnt', data=day.loc[day['season']==2], c="green")
ax2.set_title('Wiosna', fontdict=fontdict, color="green")
ax2.grid()

ax4 = fig.add_subplot(144, sharey=ax3)
ax4.scatter('temp', 'cnt', data=day.loc[day['season']==4], c="brown")
ax4.set_title('Jesień', fontdict=fontdict, color="brown")
ax4.grid()
ax4.set_xlabel("Znormalizowana temperatura", fontdict=fontdictx, position=(-1.5,0));

# %% [markdown]
# - W każdej porze roku dochodzi się do 8000 wypożyczeń
# - Zimą i latem na wyraźnie clustry
# - Wiosną i jesienią jest największy rozstrzał
